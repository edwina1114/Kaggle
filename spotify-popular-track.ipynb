# %% [markdown]
# ## Load Data

# %%
import pandas as pd
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
print("Setup Complete")
# Out:
# Setup Complete

# %%
# Set up code checking
from learntools.core import binder
binder.bind(globals())
from learntools.data_viz_to_coder.ex7 import *
print("Setup Complete")
# Out:
# Setup Complete

# %%
filepath = "../input/spotify-tracks-dataset-updated-every-week/spotify_tracks.csv"
sp_raw_data = pd.read_csv(filepath)

# %%
my_data.shape
# Out:
# (62317, 22)

# %% [markdown]
# ### Column Description
#
# https://www.kaggle.com/datasets/gauthamvijayaraj/spotify-tracks-dataset-updated-every-week/data
#
# - track_id: Spotify ID for the track.
#
# - track_name: Name of the track.
#
# - artist_name: The names of artists who performed the track, separated by commas if there are multiple artists.
#
# - year: The release year of the track.
#
# - popularity: A value between 0 and 100 indicating how popular a track is based on plays and recency.
#
# - artwork_url: URL of the album or track's artwork.
#
# - album_name: The album in which the track appears.
#
# - acousticness: A confidence measure from 0.0 to 1.0 of whether the track is acoustic.
#
# - danceability: A measure of how suitable a track is for dancing (0.0 = least danceable, 1.0 = most danceable).
#
# - duration_ms: Track length in milliseconds.
#
# - energy: A perceptual measure from 0.0 to 1.0 of intensity and activity.
#
# - key: The musical key of the track, using standard pitch class notation (e.g., 0 = C, 1 = C♯/D♭).
#
# - liveness: A measure of the likelihood that the track was recorded live (higher values indicate live performances).
#
# - loudness: The overall loudness of the track in decibels (dB).
#
# - mode: Indicates the modality of the track (1 = major, 0 = minor).
#
# - speechiness: Measures the presence of spoken words in a track (closer to 1.0 indicates more speech-like content).
#
# - tempo: The estimated tempo of the track in beats per minute (BPM).
#
# - time_signature: The number of beats per measure, ranging from 3 to 7.
#
# - valence: A measure from 0.0 to 1.0 indicating the track's musical positiveness (higher values are happier).
#
# - track_url: The Spotify URL for the track.
#
# - language: The language of the track (English, Tamil, Hindi, Telugu, Malayalam, Korean).

# %%
sp_raw_data.head()
# Out:
#                  track_id                                  track_name  \
# 0  2r0ROhr7pRN4MXDMT1fEmd                  Leo Das Entry (From "Leo")
# 1  4I38e6Dg52a2o2a8i5Q5PW                                AAO KILLELLE
# 2  59NoiRhnom3lTeRFaBzOev      Mayakiriye Sirikiriye - Orchestral EDM
# 3  5uUqRQd385pvLxC8JX3tXn    Scene Ah Scene Ah - Experimental EDM Mix
# 4  1KaBRg2xgNeCljmyxBH1mo  Gundellonaa X I Am A Disco Dancer - Mashup
#
#                                          artist_name  year  popularity  \
# 0                                Anirudh Ravichander  2024          59
# 1  Anirudh Ravichander, Pravin Mani, Vaishali Sri...  2024          47
# 2           Anirudh Ravichander, Anivee, Alvin Bruno  2024          35
# 3  Anirudh Ravichander, Bharath Sankar, Kabilan, ...  2024          24
# 4  Anirudh Ravichander, Benny Dayal, Leon James, ...  2024          22
#
#                                          artwork_url  \
# 0  https://i.scdn.co/image/ab67616d0000b273ce9c65...
# 1  https://i.scdn.co/image/ab67616d0000b273be1b03...
# 2  https://i.scdn.co/image/ab67616d0000b27334a1dd...
# 3  https://i.scdn.co/image/ab67616d0000b27332e623...
# 4  https://i.scdn.co/image/ab67616d0000b2735a59b6...
#
#                                    album_name  acousticness  danceability  \
# 0                  Leo Das Entry (From "Leo")        0.0241         0.753
# 1                                AAO KILLELLE        0.0851         0.780
# 2      Mayakiriye Sirikiriye (Orchestral EDM)        0.0311         0.457
# 3    Scene Ah Scene Ah (Experimental EDM Mix)        0.2270         0.718
# 4  Gundellonaa X I Am a Disco Dancer (Mashup)        0.0153         0.689
#
#    duration_ms  ...   key  liveness  loudness  mode  speechiness    tempo  \
# 0      97297.0  ...   8.0    0.1000    -5.994   0.0       0.1030  110.997
# 1     207369.0  ...  10.0    0.0951    -5.674   0.0       0.0952  164.995
# 2      82551.0  ...   2.0    0.0831    -8.937   0.0       0.1530  169.996
# 3     115831.0  ...   7.0    0.1240   -11.104   1.0       0.4450  169.996
# 4     129621.0  ...   7.0    0.3450    -9.637   1.0       0.1580  128.961
#
#    time_signature  valence                                          track_url  \
# 0             4.0    0.459  https://open.spotify.com/track/2r0ROhr7pRN4MXD...
# 1             3.0    0.821  https://open.spotify.com/track/4I38e6Dg52a2o2a...
# 2             4.0    0.598  https://open.spotify.com/track/59NoiRhnom3lTeR...
# 3             4.0    0.362  https://open.spotify.com/track/5uUqRQd385pvLxC...
# 4             4.0    0.593  https://open.spotify.com/track/1KaBRg2xgNeCljm...
#
#    language
# 0     Tamil
# 1     Tamil
# 2     Tamil
# 3     Tamil
# 4     Tamil
#
# [5 rows x 22 columns]

# %%
sp_raw_data.describe(include='all')
# Out:
#                       track_id                       track_name  \
# count                    62317                            62317
# unique                   62239                            41521
# top     0nLLe981VCdAkZXXxXrbPn  Merry Christmas, Happy Holidays
# freq                         2                              151
# mean                       NaN                              NaN
# std                        NaN                              NaN
# min                        NaN                              NaN
# 25%                        NaN                              NaN
# 50%                        NaN                              NaN
# 75%                        NaN                              NaN
# max                        NaN                              NaN
#
#               artist_name          year    popularity  \
# count               62317  62317.000000  62317.000000
# unique              12513           NaN           NaN
# top     Shankar Mahadevan           NaN           NaN
# freq                 1391           NaN           NaN
# mean                  NaN   2014.425935     15.358361
# std                   NaN      9.645113     18.626908
# min                   NaN   1971.000000      0.000000
# 25%                   NaN   2011.000000      0.000000
# 50%                   NaN   2017.000000      7.000000
# 75%                   NaN   2022.000000     26.000000
# max                   NaN   2024.000000     93.000000
#
#                                               artwork_url  \
# count                                               62317
# unique                                              21110
# top     https://i.scdn.co/image/ab67616d0000b273bf257e...
# freq                                                  186
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                           album_name  acousticness  danceability  \
# count                          62317  62317.000000  62317.000000
# unique                         19898           NaN           NaN
# top     Nowhere to Hide (Unabridged)           NaN           NaN
# freq                             186           NaN           NaN
# mean                             NaN      0.362292      0.596807
# std                              NaN      0.314609      0.186209
# min                              NaN     -1.000000     -1.000000
# 25%                              NaN      0.067100      0.497000
# 50%                              NaN      0.286000      0.631000
# 75%                              NaN      0.632000      0.730000
# max                              NaN      0.996000      0.986000
#
#          duration_ms  ...           key      liveness       loudness  \
# count   6.231700e+04  ...  62317.000000  62317.000000   62317.000000
# unique           NaN  ...           NaN           NaN            NaN
# top              NaN  ...           NaN           NaN            NaN
# freq             NaN  ...           NaN           NaN            NaN
# mean    2.425270e+05  ...      5.101658      0.194143     -65.103433
# std     1.129999e+05  ...      3.553469      0.172030    2369.051478
# min     5.000000e+03  ...     -1.000000     -1.000000 -100000.000000
# 25%     1.921600e+05  ...      2.000000      0.093200     -10.727000
# 50%     2.362670e+05  ...      5.000000      0.125000      -7.506000
# 75%     2.862400e+05  ...      8.000000      0.243000      -5.456000
# max     4.581483e+06  ...     11.000000      0.998000       1.233000
#
#                 mode   speechiness         tempo  time_signature  \
# count   62317.000000  62317.000000  62317.000000    62317.000000
# unique           NaN           NaN           NaN             NaN
# top              NaN           NaN           NaN             NaN
# freq             NaN           NaN           NaN             NaN
# mean        0.586052      0.087722    117.931247        3.857086
# std         0.493682      0.115150     28.509459        0.502660
# min        -1.000000     -1.000000     -1.000000       -1.000000
# 25%         0.000000      0.036700     95.942000        4.000000
# 50%         1.000000      0.048900    117.991000        4.000000
# 75%         1.000000      0.089100    135.081000        4.000000
# max         1.000000      0.959000    239.970000        5.000000
#
#              valence                                          track_url  \
# count   62317.000000                                              62317
# unique           NaN                                              62239
# top              NaN  https://open.spotify.com/track/0nLLe981VCdAkZX...
# freq             NaN                                                  2
# mean        0.495226                                                NaN
# std         0.264787                                                NaN
# min        -1.000000                                                NaN
# 25%         0.292000                                                NaN
# 50%         0.507000                                                NaN
# 75%         0.710000                                                NaN
# max         0.995000                                                NaN
#
#         language
# count      62317
# unique         7
# top      English
# freq       23392
# mean         NaN
# std          NaN
# min          NaN
# 25%          NaN
# 50%          NaN
# 75%          NaN
# max          NaN
#
# [11 rows x 22 columns]

# %%
sp_raw_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62317 entries, 0 to 62316
# Data columns (total 22 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   track_id          62317 non-null  object
#  1   track_name        62317 non-null  object
#  2   artist_name       62317 non-null  object
#  3   year              62317 non-null  int64
#  4   popularity        62317 non-null  int64
#  5   artwork_url       62317 non-null  object
#  6   album_name        62317 non-null  object
#  7   acousticness      62317 non-null  float64
#  8   danceability      62317 non-null  float64
#  9   duration_ms       62317 non-null  float64
#  10  energy            62317 non-null  float64
#  11  instrumentalness  62317 non-null  float64
#  12  key               62317 non-null  float64
#  13  liveness          62317 non-null  float64
#  14  loudness          62317 non-null  float64
#  15  mode              62317 non-null  float64
#  16  speechiness       62317 non-null  float64
#  17  tempo             62317 non-null  float64
#  18  time_signature    62317 non-null  float64
#  19  valence           62317 non-null  float64
#  20  track_url         62317 non-null  object
#  21  language          62317 non-null  object
# dtypes: float64(13), int64(2), object(7)
# memory usage: 10.5+ MB

# %% [markdown]
# ## Check for null values
#
# No null values -> No need to deal with null values.

# %%
sp_raw_data.isnull().sum()
# Out:
# track_id            0
# track_name          0
# artist_name         0
# year                0
# popularity          0
# artwork_url         0
# album_name          0
# acousticness        0
# danceability        0
# duration_ms         0
# energy              0
# instrumentalness    0
# key                 0
# liveness            0
# loudness            0
# mode                0
# speechiness         0
# tempo               0
# time_signature      0
# valence             0
# track_url           0
# language            0
# dtype: int64

# %% [markdown]
# ## Visualize the data

# %% [markdown]
# ### Conclusion
#
# * The popularity of KPOP is the hottest.

# %%
language_popularity = sp_raw_data.groupby('language').agg({'popularity': 'mean',
                                                           'danceability': 'mean',
                                                           'energy': 'mean',
                                                           'tempo': 'mean',
                                                        'duration_ms': 'mean'}).reset_index()
language_popularity
# Out:
#     language  popularity  danceability    energy       tempo    duration_ms
# 0    English   14.762312      0.535761  0.530755  116.759265  223991.252180
# 1      Hindi   18.195645      0.604054  0.653893  115.690966  260066.207143
# 2     Korean   27.548092      0.638057  0.757407  122.193436  210295.684753
# 3  Malayalam    7.315603      0.635894  0.675103  116.815089  243043.553191
# 4      Tamil   11.932971      0.657299  0.619543  119.009386  251032.409668
# 5     Telugu   14.200617      0.637809  0.670682  120.120586  232252.845679
# 6    Unknown   12.260592      0.620692  0.606849  117.687376  277160.769473

# %%
genre = ['popularity', 'danceability', 'energy', 'tempo', 'duration_ms']

for i, feature in enumerate(genre):
    plt.subplot(3,2, i+1)
    sns.barplot(x='language', y=feature, data=language_popularity)
    plt.title(f"Language vs {feature}")
    plt.xlabel(f"Language")
    plt.ylabel(f"{feature}")
    plt.tight_layout()

# %%
k_songs = sp_raw_data[sp_raw_data.language == 'Korean']
k_songs
# Out:
#                      track_id  \
# 7438   1TpC2MWyUbQaiJrt6RUDdH
# 15976  3FdG6bmED6q3L1UNVVIkiB
# 24523  5IAESfJjmOYu7cHyX557kz
# 24524  4IJsVXbSeGPUrgwpVoHmlg
# 24525  69xohKu8C1fsflYAiSNbwM
# ...                       ...
# 35850  3JQJxRewX63qyISEfKMWSn
# 35851  2OoUOxtlxf7qqVVFziLKL3
# 35852  4Vqal5XldhTbPiJ45zLq1c
# 35853  1bwXbfm8EqkbJUje93EpJb
# 35854  4fle8ASrBFWnnd1qP0Ujbb
#
#                                               track_name  \
# 7438                              Sun Bhi Le - Lofi Flip
# 15976                          Mera Love Main - Lofi Mix
# 24523                                           Take Two
# 24524                                         The Planet
# 24525                                            Run BTS
# ...                                                  ...
# 35850  Coji De Portocale ( Cu aroma de Craciun - Exte...
# 35851  Coji de portocale ( by Music Pink Elephant) - ...
# 35852  Coji de portocale - Cu aroma de Craciun Extend...
# 35853            Coji de portocale - Cu aroma de Craciun
# 35854           Coji De Portocale ( Cu aroma de Craciun)
#
#                                              artist_name  year  popularity  \
# 7438   Arijit Singh, Vishal Mishra, Raj Shekhar, Jamm...  2023           5
# 15976        Amit Trivedi, Swanand Kirkire, Jammy Weirdo  2023           1
# 24523                                                BTS  2023          76
# 24524                                                BTS  2023          65
# 24525                                                BTS  2022          78
# ...                                                  ...   ...         ...
# 35850                                               BiBi  2016           0
# 35851                                               BiBi  2016           2
# 35852                                               BiBi  2016           0
# 35853                                               BiBi  2016           0
# 35854                                               BiBi  2016           0
#
#                                              artwork_url  \
# 7438   https://i.scdn.co/image/ab67616d0000b2733244ad...
# 15976  https://i.scdn.co/image/ab67616d0000b273775cc4...
# 24523  https://i.scdn.co/image/ab67616d0000b2738a701e...
# 24524  https://i.scdn.co/image/ab67616d0000b273fa5524...
# 24525  https://i.scdn.co/image/ab67616d0000b27317db30...
# ...                                                  ...
# 35850  https://i.scdn.co/image/ab67616d0000b2733f3be1...
# 35851  https://i.scdn.co/image/ab67616d0000b2732859f5...
# 35852  https://i.scdn.co/image/ab67616d0000b27372caf1...
# 35853  https://i.scdn.co/image/ab67616d0000b27372caf1...
# 35854  https://i.scdn.co/image/ab67616d0000b2733f3be1...
#
#                                               album_name  acousticness  \
# 7438                              Sun Bhi Le (Lofi Flip)      0.017800
# 15976                          Mera Love Main (Lofi Mix)      0.024600
# 24523                                           Take Two      0.026800
# 24524                                         The Planet      0.000482
# 24525                                              Proof      0.020100
# ...                                                  ...           ...
# 35850  Coji de portocale (Cu aroma de Craciun) [Produ...      0.096000
# 35851  Coji de portocale ( by Music Pink Elephant) [P...      0.375000
# 35852  Coji de portocale (Cu aroma de Craciun - Produ...      0.096000
# 35853  Coji de portocale (Cu aroma de Craciun - Produ...      0.123000
# 35854  Coji de portocale (Cu aroma de Craciun) [Produ...      0.135000
#
#        danceability  duration_ms  ...   key  liveness  loudness  mode  \
# 7438          0.408     189000.0  ...   0.0    0.5430   -18.836   1.0
# 15976         0.502     176727.0  ...  11.0    0.7880   -18.058   1.0
# 24523         0.617     229953.0  ...   7.0    0.3780    -5.978   1.0
# 24524         0.665     178156.0  ...   0.0    0.2000    -3.619   1.0
# 24525         0.724     204940.0  ...   8.0    0.0358    -3.747   1.0
# ...             ...          ...  ...   ...       ...       ...   ...
# 35850         0.793     260339.0  ...   8.0    0.0794    -7.759   1.0
# 35851         0.804     198814.0  ...   5.0    0.4060    -7.479   0.0
# 35852         0.793     260339.0  ...   8.0    0.0794    -7.759   1.0
# 35853         0.712     198597.0  ...   8.0    0.3870    -7.317   1.0
# 35854         0.771     201356.0  ...   8.0    0.3570    -7.334   1.0
#
#        speechiness    tempo  time_signature  valence  \
# 7438        0.0445  160.015             4.0   0.0392
# 15976       0.0348  110.071             4.0   0.0687
# 24523       0.0345   92.991             4.0   0.5660
# 24524       0.0708  119.986             4.0   0.6870
# 24525       0.1680   77.004             4.0   0.6960
# ...            ...      ...             ...      ...
# 35850       0.1080  117.931             4.0   0.5050
# 35851       0.0959  118.021             4.0   0.4130
# 35852       0.1080  117.931             4.0   0.5050
# 35853       0.1210  117.747             4.0   0.4770
# 35854       0.0679  117.970             4.0   0.4260
#
#                                                track_url  language
# 7438   https://open.spotify.com/track/1TpC2MWyUbQaiJr...    Korean
# 15976  https://open.spotify.com/track/3FdG6bmED6q3L1U...    Korean
# 24523  https://open.spotify.com/track/5IAESfJjmOYu7cH...    Korean
# 24524  https://open.spotify.com/track/4IJsVXbSeGPUrgw...    Korean
# 24525  https://open.spotify.com/track/69xohKu8C1fsflY...    Korean
# ...                                                  ...       ...
# 35850  https://open.spotify.com/track/3JQJxRewX63qyIS...    Korean
# 35851  https://open.spotify.com/track/2OoUOxtlxf7qqVV...    Korean
# 35852  https://open.spotify.com/track/4Vqal5XldhTbPiJ...    Korean
# 35853  https://open.spotify.com/track/1bwXbfm8EqkbJUj...    Korean
# 35854  https://open.spotify.com/track/4fle8ASrBFWnnd1...    Korean
#
# [6893 rows x 22 columns]
